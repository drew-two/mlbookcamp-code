# %% [markdown]
# ## Homework
#
# In this homework, we'll deploy Credit Card prediction model from the homework 5.
# We already have a docker image for this model - we'll use it for
# deploying the model to Kubernetes.
#
#
# ## Bulding the image
#
# Clone the course repo if you haven't:
#
# ```
# git clone https://github.com/alexeygrigorev/mlbookcamp-code.git
# ```
#
# Go to the `course-zoomcamp/cohorts/2022/05-deployment/homework` folder and
# execute the following:
#
#
# ```bash
# docker build -t zoomcamp-model:v001 .
# ```
#
# > **Note:** If you have troubles building the image, you can
# > use the image we built and published to docker hub:
# > `svizor42/zoomcamp-model:v001`

# %%
# !cd ../05-deployment/homework && docker build -t zoomcamp-model:v001 .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (4/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 27B                                           0.1s
#  => [2/5] RUN pip install pipenv                                           0.1s
# [+] Building 0.3s (4/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 27B                                           0.2s
#  => [2/5] RUN pip install pipenv                                           0.2s
# [+] Building 0.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           0.4s
# [+] Building 0.6s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           0.5s
# [+] Building 0.8s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           0.7s
# [+] Building 0.9s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           0.8s
# [+] Building 1.1s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.0s
# [+] Building 1.2s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.1s
# [+] Building 1.4s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.3s
# [+] Building 1.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.4s
# [+] Building 1.7s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.6s
# [+] Building 1.8s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.7s
# [+] Building 2.0s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           1.9s
# [+] Building 2.1s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.0s
# [+] Building 2.3s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.2s
# [+] Building 2.4s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.3s
# [+] Building 2.6s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.5s
# [+] Building 2.7s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.6s
# [+] Building 2.9s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.8s
# [+] Building 3.0s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           2.9s
# [+] Building 3.2s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.1s
# [+] Building 3.3s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.2s
#  => => # Collecting pipenv
# [+] Building 3.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.4s
#  => => # Collecting pipenv
# [+] Building 3.6s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.5s
#  => => # Collecting pipenv
# [+] Building 3.8s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.7s
#  => => # Collecting pipenv
# [+] Building 3.9s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           3.8s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.1s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.0s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.2s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.1s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.4s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.3s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.4s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.7s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.6s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 4.8s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.7s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.0s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           4.9s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.1s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.0s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.3s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.2s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.4s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.3s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.6s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.5s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.7s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.6s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 5.9s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.8s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 6.0s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           5.9s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
# [+] Building 6.2s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.1s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
# [+] Building 6.3s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.2s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
# [+] Building 6.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.4s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
# [+] Building 6.6s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.5s
#  => => # Collecting pipenv
#  => => #   Downloading pipenv-2022.11.30-py3-none-any.whl (2.9 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
# [+] Building 6.8s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.7s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 6.9s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           6.8s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 7.1s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           7.0s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 7.2s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           7.1s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 7.4s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           7.3s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 7.5s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                           7.4s
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.2 MB/s eta
#  => => # 0:00:00
#  => => # Collecting virtualenv-clone>=0.2.5
#  => => #   Downloading virtualenv_clone-0.5.7-py3-none-any.whl (6.6 kB)
#  => => # Collecting virtualenv
#  => => #   Downloading virtualenv-20.17.0-py3-none-any.whl (8.8 MB)
# [+] Building 7.7s (5/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
# ...
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 82.3s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 82.4s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
# [+] Building 82.6s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 82.7s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 82.9s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 83.0s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 83.2s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 83.3s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 83.5s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 83.6s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.6s
#  => => exporting layers                                                    1.6s
# [+] Building 83.8s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 83.9s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
# [+] Building 84.0s (10/10) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 302B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/svizor/zoomcamp-model:3.9.12-s  0.0s
#  => CACHED [1/5] FROM docker.io/svizor/zoomcamp-model:3.9.12-slim          0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 16.71kB                                       0.2s
#  => [2/5] RUN pip install pipenv                                          16.6s
#  => [3/5] COPY [Pipfile, Pipfile.lock, ./]                                 0.0s
#  => [4/5] RUN pipenv install --system --deploy                            65.3s
#  => [5/5] COPY [q6_predict.py, ./]                                         0.0s
#  => exporting to image                                                     1.9s
#  => => exporting layers                                                    1.9s
#  => => writing image sha256:b647ce8124835a218fe8da6b971adfa75f6b58b91d6de  0.0s
#  => => naming to docker.io/library/zoomcamp-model:v001                     0.0s

# %% [markdown]
# ### Question 1
#
# Run it to test that it's working locally:
#
# ```bash
# docker run -it --rm -p 9696:9696 zoomcamp-model:v001
# ```
#
# And in another terminal, execute `q6_test.py` file:
#
# ```bash
# python q6_test.py
# ```
#
# You should see this:
#
# ```
# {'get_card': True, 'get_card_probability': <value>}
# ```
#
# Here `<value>` is the probability of getting a credit card. You need to choose the right one.
#
# * 0.289
# * 0.502
# * 0.769
# * 0.972
#
# Now you can stop the container running in Docker.

# %%
# !python q6_test.py
# Out:
# {'get_card': True, 'get_card_probability': 0.7692649226628628}

# %% [markdown]
# Answer: 0.769

# %% [markdown]
# ### Question 2
#
# What's the version of `kind` that you have?
#
# Use `kind --version` to find out.
#
#
# ### Creating a cluster
#
# Now let's create a cluster with `kind`:
#
# ```bash
# kind create cluster
# ```
#
# And check with `kubectl` that it was successfully created:
#
# ```bash
# kubectl cluster-info
# ```

# %%
# !kind --version
# Out:
# kind version 0.17.0

# %%
# !kubectl cluster-info
# Out:
# Kubernetes control plane is running at https://127.0.0.1:38121
# CoreDNS is running at https://127.0.0.1:38121/api/v1/namespaces/kube-system/services/kube-dns:dns/proxy
#
# To further debug and diagnose cluster problems, use 'kubectl cluster-info dump'.

# %% [markdown]
# ### Question 3
#
# What's the smallest deployable computing unit that we can create and manage
# in Kubernetes (`kind` in our case)?
#
# * Node
# * Pod
# * Deployment
# * Service

# %% [markdown]
# Answer: Pod

# %% [markdown]
# ### Question 4
#
# Now let's test if everything works. Use `kubectl` to get the list of running services.
#
# What's the `Type` of the service that is already running there?
#
# * ClusterIP
# * NodePort
# * LoadBalancer
# * ExternalName

# %%
# !kubectl get svc
# Out:
# NAME         TYPE        CLUSTER-IP   EXTERNAL-IP   PORT(S)   AGE
# kubernetes   ClusterIP   10.96.0.1    <none>        443/TCP   28s

# %% [markdown]
# Answer: ClusterIP

# %% [markdown]
# ### Question 5
#
# To be able to use the docker image we previously created (`zoomcamp-model:v001`),
# we need to register it with `kind`.
#
# What's the command we need to run for that?
#
# * `kind create cluster`
# * `kind build node-image`
# * `kind load docker-image`
# * `kubectl apply`

# %%
# Doing this now will save some time
# !kind load docker-image zoomcamp-model:v001
# Out:
# Image: "" with ID "sha256:b647ce8124835a218fe8da6b971adfa75f6b58b91d6def1b9bb4e5a6c4f0e7bc" not yet present on node "kind-control-plane", loading...

# %% [markdown]
# Answer: `kind load docker-image`

# %% [markdown]
# ### Question 6
#
# Now let's create a [deployment config](./deployment.yaml)

# %%
# !kubectl apply -f deployment.yaml
# Out:
# deployment.apps/credit-card created

# %%
# !kubectl get pods
# Out:
# NAME                           READY   STATUS    RESTARTS   AGE
# credit-card-6f988cd849-84b2z   1/1     Running   0          10s

# %% [markdown]
# Answer: 9696

# %% [markdown]
# ### Question 6
#
# Now let's create a [service config](./service.yaml)

# %%
# !kubectl apply -f service.yaml
# Out:
# service/credit-card created

# %%
# !kubectl get svc
# Out:
# NAME          TYPE        CLUSTER-IP      EXTERNAL-IP   PORT(S)   AGE
# credit-card   ClusterIP   10.96.140.170   <none>        80/TCP    82s
# kubernetes    ClusterIP   10.96.0.1       <none>        443/TCP   5m6s

# %% [markdown]
# Answer: credit-card

# %% [markdown]
# ### Testing the service
#
# We can test our service locally by forwarding the port 9696 on our computer
# to the port 80 on the service:
#
# ```bash
# kubectl port-forward service/<Service name> 9696:80
# ```
#
# Run `q6_test.py` (from the homework 5) once again to verify that everything is working.
# You should get the same result as in Question 1.

# %%
# The port is being forwarded in another terminal
# !python q6_test.py
# Out:
# {'get_card': True, 'get_card_probability': 0.7692649226628628}

# %% [markdown]
# ### Autoscaling
#
# Now we're going to use a [HorizontalPodAutoscaler](https://kubernetes.io/docs/tasks/run-application/horizontal-pod-autoscale-walkthrough/)
# (HPA for short) that automatically updates a workload resource (such as our deployment),
# with the aim of automatically scaling the workload to match demand.
#
# Use the following command to create the HPA:

# %%
# !kubectl autoscale deployment credit-card --name credit-card-hpa --cpu-percent=20 --min=1 --max=3
# Out:
# horizontalpodautoscaler.autoscaling/credit-card-hpa autoscaled

# %% [markdown]
# You can check the current status of the new HPA by running:

# %%
# !kubectl get hpa
# Out:
# NAME              REFERENCE                TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# credit-card-hpa   Deployment/credit-card   <unknown>/20%   1         3         1          3s

# %% [markdown]
# The output should be similar to the next:
#
# ```bash
# NAME              REFERENCE                TARGETS   MINPODS   MAXPODS   REPLICAS   AGE
# credit-card-hpa   Deployment/credit-card   1%/20%    1         3         1          27s
# ```
#
# `TARGET` column shows the average CPU consumption across all the Pods controlled by the corresponding deployment.
# Current CPU consumption is about 0% as there are no clients sending requests to the server.
# >
# >Note: In case the HPA instance doesn't run properly, try to install the latest Metrics Server release
# > from the `components.yaml` manifest:
# > ```bash
# > kubectl apply -f https://github.com/kubernetes-sigs/metrics-server/releases/latest/download/components.yaml
# >```

# %%
# !kubectl apply -f https://github.com/kubernetes-sigs/metrics-server/releases/latest/download/components.yaml
# Out:
# serviceaccount/metrics-server unchanged
# clusterrole.rbac.authorization.k8s.io/system:aggregated-metrics-reader unchanged
# clusterrole.rbac.authorization.k8s.io/system:metrics-server unchanged
# rolebinding.rbac.authorization.k8s.io/metrics-server-auth-reader unchanged
# clusterrolebinding.rbac.authorization.k8s.io/metrics-server:system:auth-delegator unchanged
# clusterrolebinding.rbac.authorization.k8s.io/system:metrics-server unchanged
# service/metrics-server unchanged
# deployment.apps/metrics-server configured
# apiservice.apiregistration.k8s.io/v1beta1.metrics.k8s.io unchanged

# %% [markdown]
# ## Increase the load
#
# Let's see how the autoscaler reacts to increasing the load. To do this, we can slightly modify the existing
# [`q6_test.py`](./q6_test.py) script by putting the operator that sends the request to the credit-card service into a loop.
#
# ```python
# while True:
#     sleep(0.1)
#     response = requests.post(url, json=client).json()
#     print(response)
# ```
#
# Now you can run this script.

# %% [markdown]
# ### Question 8 (optional)
#
# Run `kubectl get hpa credit-card-hpa --watch` command to monitor how the autoscaler performs.
# Within a minute or so, you should see the higher CPU load; and then - more replicas.
# What was the maximum amount of the replicas during this test?
#
#
# * 1
# * 2
# * 3
# * 4
#
# >Note: It may take a few minutes to stabilize the number of replicas. Since the amount of load is not controlled
# > in any way it may happen that the final number of replicas will differ from initial.

# %%
# !kubectl get hpa credit-card-hpa --watch
# Out:
# NAME              REFERENCE                TARGETS         MINPODS   MAXPODS   REPLICAS   AGE
# credit-card-hpa   Deployment/credit-card   <unknown>/20%   1         3         1          10s
# ^C

# %% [markdown]
# Answer: 1 (could not get anything to change)
